# %%
# Out:
#     OrderID CustomerID  Gender  Age       City          Product     Category  \
# 0      1001       C001    Male   22    Karachi           Laptop  Electronics
# 1      1002       C002  Female   25     Lahore       Headphones  Electronics
# 2      1003       C003    Male   30  Islamabad            Shirt      Fashion
# 3      1004       C004  Female   28    Karachi            Shoes      Fashion
# 4      1005       C005    Male   35   Peshawar           Mobile  Electronics
# 5      1006       C006  Female   19     Quetta              Bag      Fashion
# 6      1007       C007    Male   40    Karachi               TV  Electronics
# 7      1008       C008  Female   27     Lahore            Watch  Accessories
# 8      1009       C009    Male   31  Islamabad         Keyboard  Electronics
# 9      1010       C010  Female   23    Karachi       Makeup Kit       Beauty
# 10     1011       C011    Male   29     Multan            Shoes      Fashion
# ...

# %%
# Out:
# (25, 13)

# %%
# Out:
# Index(['OrderID', 'CustomerID', 'Gender', 'Age', 'City', 'Product', 'Category',
#        'Price', 'Quantity', 'OrderDate', 'PaymentMethod', 'Rating',
#        'Discount'],
#       dtype='object')

# %%
# Out:
#    OrderID CustomerID  Gender  Age       City     Product     Category  \
# 0     1001       C001    Male   22    Karachi      Laptop  Electronics
# 1     1002       C002  Female   25     Lahore  Headphones  Electronics
# 2     1003       C003    Male   30  Islamabad       Shirt      Fashion
# 3     1004       C004  Female   28    Karachi       Shoes      Fashion
# 4     1005       C005    Male   35   Peshawar      Mobile  Electronics
# 5     1006       C006  Female   19     Quetta         Bag      Fashion
# 6     1007       C007    Male   40    Karachi          TV  Electronics
# 7     1008       C008  Female   27     Lahore       Watch  Accessories
# 8     1009       C009    Male   31  Islamabad    Keyboard  Electronics
# 9     1010       C010  Female   23    Karachi  Makeup Kit       Beauty
#
#     Price  Quantity   OrderDate PaymentMethod  Rating  Discount
# 0  120000         1  05/01/2025   Credit Card       4        10
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        25 non-null     int64
#  1   CustomerID     25 non-null     object
#  2   Gender         25 non-null     object
#  3   Age            25 non-null     int64
#  4   City           25 non-null     object
#  5   Product        25 non-null     object
#  6   Category       25 non-null     object
#  7   Price          25 non-null     int64
#  8   Quantity       25 non-null     int64
#  9   OrderDate      25 non-null     object
#  10  PaymentMethod  25 non-null     object
#  11  Rating         25 non-null     int64
#  12  Discount       25 non-null     int64
# dtypes: int64(6), object(7)
# memory usage: 2.7+ KB

# %%
# Out:
# City
# Karachi      8
# Lahore       5
# Islamabad    5
# Quetta       3
# Peshawar     2
# Multan       2
# Name: count, dtype: int64

# %%
# Out:
# City
# Karachi      8
# Lahore       5
# Islamabad    5
# Quetta       3
# Peshawar     2
# Multan       2
# Name: count, dtype: int64

# %%
# Out:
# 29

# %%
# Out:
# 0     120000
# 1      10000
# 2       7500
# 3       7000
# 4      80000
# 5       6000
# 6     150000
# 7      10000
# 8       7000
# 9       4500
# 10     13000
# 11      8000
# 12      6000
# 13      9000
# 14    120000
# 15     50000
# 16      6000
# 17     60000
# 18     95000
# 19      7000
# 20     17000
# 21      6000
# 22    180000
# 23      2400
# 24      9000
# dtype: int64

# %%
# Out:
#     OrderID CustomerID  Gender  Age       City          Product     Category  \
# 16     1017       C017    Male   24    Karachi          T-shirt      Fashion
# 12     1013       C013    Male   26    Karachi            Mouse  Electronics
# 2      1003       C003    Male   30  Islamabad            Shirt      Fashion
# 21     1022       C022  Female   28     Quetta         Lipstick       Beauty
# 23     1024       C024  Female   22     Lahore            Scarf      Fashion
# 5      1006       C006  Female   19     Quetta              Bag      Fashion
# 20     1021       C021    Male   34     Multan         Sneakers      Fashion
# 8      1009       C009    Male   31  Islamabad         Keyboard  Electronics
# 10     1011       C011    Male   29     Multan            Shoes      Fashion
# 1      1002       C002  Female   25     Lahore       Headphones  Electronics
# 15     1016       C016  Female   38   Peshawar             Oven   Appliances
# ...

# %%
# Out:
#     OrderID CustomerID  Gender  Age       City   Product     Category  Price  \
# 16     1017       C017    Male   24    Karachi   T-shirt      Fashion   1500
# 12     1013       C013    Male   26    Karachi     Mouse  Electronics   2000
# 2      1003       C003    Male   30  Islamabad     Shirt      Fashion   2500
# 21     1022       C022  Female   28     Quetta  Lipstick       Beauty   2000
# 23     1024       C024  Female   22     Lahore     Scarf      Fashion   1200
#
#     Quantity   OrderDate PaymentMethod  Rating  Discount
# 16         4  22/01/2025     EasyPaisa       5         5
# 12         3  18/01/2025      JazzCash       4         5
# 2          3  08/01/2025    Debit Card       3        15
# 21         3  27/01/2025     EasyPaisa       5        20
# 23         2  29/01/2025    Debit Card       4         5

# %%
# Out:
# Category
# Electronics    9
# Fashion        8
# Beauty         3
# Appliances     3
# Accessories    2
# Name: count, dtype: int64

# %%
# Out:
# MALE COUNT IS 13 & FEMALE COUNT IS 12

# %%
# Out:
# Category
# Accessories    4.500000
# Appliances     3.666667
# Beauty         4.666667
# Electronics    4.444444
# Fashion        3.750000
# Name: Rating, dtype: float64

# %%
# Out:
# City
# Islamabad    127500
# Karachi      480500
# Lahore        90400
# Multan        30000
# Peshawar     130000
# Quetta       132000
# Name: Totalrevenue, dtype: int64

# %%
# Out:
#     OrderID CustomerID  Gender  Age       City          Product     Category  \
# 22     1023       C023    Male   41    Karachi  Air Conditioner   Appliances
# 6      1007       C007    Male   40    Karachi               TV  Electronics
# 14     1015       C015    Male   45     Quetta           Fridge   Appliances
# 0      1001       C001    Male   22    Karachi           Laptop  Electronics
# 18     1019       C019    Male   32  Islamabad           Camera  Electronics
# 4      1005       C005    Male   35   Peshawar           Mobile  Electronics
# 17     1018       C018  Female   29     Lahore           Tablet  Electronics
# 15     1016       C016  Female   38   Peshawar             Oven   Appliances
# 7      1008       C008  Female   27     Lahore            Watch  Accessories
# 24     1025       C025    Male   37  Islamabad          Speaker  Electronics
# 13     1014       C014  Female   21  Islamabad            Dress      Fashion
# ...

# %%
# Out:
#     OrderID CustomerID  Gender  Age       City     Product     Category  \
# 6      1007       C007    Male   40    Karachi          TV  Electronics
# 13     1014       C014  Female   21  Islamabad       Dress      Fashion
# 3      1004       C004  Female   28    Karachi       Shoes      Fashion
# 19     1020       C020  Female   26    Karachi     Handbag  Accessories
# 9      1010       C010  Female   23    Karachi  Makeup Kit       Beauty
# 21     1022       C022  Female   28     Quetta    Lipstick       Beauty
#
#      Price  Quantity   OrderDate PaymentMethod  Rating  Discount  Totalrevenue
# 6   150000         1  12/01/2025          Cash       4        18        150000
# 13    9000         1  19/01/2025    Debit Card       5        25          9000
# 3     7000         1  09/01/2025     EasyPaisa       4        20          7000
# 19    7000         1  25/01/2025      JazzCash       4        18          7000
# ...
